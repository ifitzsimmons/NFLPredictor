# %%
import csv
import json
import os
import re

from collections import defaultdict, OrderedDict

# %%
def remove_special_characters(match_string):
    return re.sub("(\/)|(\d)|(\.)|(')|(-)|(\s+)", '', match_string)

# %% [markdown]
# # Constants

# %%
nfl_acronym_team_map = {
    'Arizona Cardinals':'ARI', 
    'Atlanta Falcons':'ATL', 
    'Baltimore Ravens':'BAL', 
    'Buffalo Bills':'BUF', 
    'Carolina Panthers':'CAR', 
    'Chicago Bears':'CHI', 
    'Cincinnati Bengals':'CIN', 
    'Cleveland Browns':'CLE', 
    'Dallas Cowboys':'DAL', 
    'Denver Broncos':'DEN', 
    'Detroit Lions':'DET', 
    'Green Bay Packers':'GNB', 
    'Houston Texans':'HOU', 
    'Indianapolis Colts':'IND', 
    'Jacksonville Jaguars':'JAX', 
    'Kansas City Chiefs':'KAN', 
    'Las Vegas Raiders':'LVR', 
    'Los Angeles Chargers':'LAC', 
    'Los Angeles Rams':'LAR', 
    'Miami Dolphins':'MIA', 
    'Minnesota Vikings':'MIN', 
    'New England Patriots':'NWE', 
    'New Orleans Saints':'NOR', 
    'New York Giants':'NYG', 
    'New York Jets':'NYJ', 
    'Oakland Raiders':'OAK', 
    'Philadelphia Eagles':'PHI', 
    'Pittsburgh Steelers':'PIT', 
    'San Diego Chargers':'SDG', 
    'San Francisco 49ers':'SEA', 
    'Seattle Seahawks':'SEA', 
    'St. Louis Rams':'STL', 
    'Tampa Bay Buccaneers':'TAM', 
    'Tennessee Titans': 'TEN', 
    'Washington Football Team':'WAS',
    'Washington Redskins': 'WAS'
}

# %% [markdown]
# # Set professional matching data
#
# Create a "match object" for each player in the NFL dataset.

# %%
with open('./ProData/cleaned/player_id_info.json', 'r') as nfl_data_file:
    nfl_name_data = json.load(nfl_data_file)

# %%
nfl_match_data = {}
for player_id, player_data in nfl_name_data.items():
    match_string = f'{player_data["name"]}{player_data["position"]}'
    matching_data = {
        'nfl_name': player_data['name'],
        'nfl_position': player_data['position'],
        'nfl_id': player_id,
        'nfl_match_string': remove_special_characters(match_string).lower()
    }
    nfl_match_data[player_id] = matching_data

# %% [markdown]
# ### Add draft data
# Add draft data to the match object for each player

# %%
all_draft_data = {}
for _, _, files in os.walk('./ProData/cleaned/draft_data'):
    for file in files:
        with open(f'./ProData/cleaned/draft_data/{file}', 'r') as draft_data_file:
            data = json.load(draft_data_file)
            all_draft_data = {**data, **all_draft_data}

# %%
for player_id, plyr_draft_data in all_draft_data.items():
    team_acronym = plyr_draft_data['team']
    draft_pick = plyr_draft_data['draft_pick']
    
    nfl_name = nfl_match_data[player_id]['nfl_name']
    match_string = f'{remove_special_characters(nfl_name)}{draft_pick}'
    
    nfl_match_data[player_id]['nfl_drafted_by'] = plyr_draft_data['team']
    nfl_match_data[player_id]['nfl_overall_pick'] = plyr_draft_data['draft_pick']
    nfl_match_data[player_id]['nfl_match_string'] = match_string.lower()

# %% [markdown]
# # Load college data
# Create match object for each player from the college dataset

# %%
with open('./CollegeData/draftedBy.json', 'r') as college_draft_file:
    college_draft_data = json.load(college_draft_file)

for player in college_draft_data:
    player_id = player['playerId']
    draft_pick = player['draftedOverall']

    match_string = f'{remove_special_characters(player_id)}{draft_pick}'

    player['match_string'] = match_string.lower()
    try:
        player['draftedBy'] = nfl_acronym_team_map[player['draftedBy']]
    except:
        player['invalidTeam'] = True
        continue
    
college_draft_data_clean = [player for player in college_draft_data if 'invalidTeam' not in player]

# %% [markdown]
# # Match

# %% [markdown]
# ## Match NFL players and college players
# In order to match college and NFL players we perform fuzzy matching for each professional player against all college players in the dataset. In order to account for misspellings and duplicate names, we decided to match based on name and overall draft position (to make this most accurate, we would have needed the "year drafted" from the college data, which is not present). However, we felt comfortable with the risk that two players with the exact same name would be drafted in the exact same spot over two drafts.
#
# The matching process is defined as follows:
# 1. From college and NFL dataset combine the players name and overall draft position
#     * Player names were standardized by removing all special characters, white spaces, and numbers and then converted to lower case.
# 2. In order to be considered for a match, the two strings would need to have a match ratio of **60% or greater**
# 3. The college player that produces the highest match score will be saved for each NFL player.
# 4. To protect against false positives, we will consider a match to only be true if both of the following conditions are true:
#     * The team that drafted the player from the college dataset matches the team that drafted the player from the NFL dataset
#     * The overall draft pick from the college dataset matches the overall draft pick from the NFL dataset.

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
matches = []

min_score = 60

for pro_data in nfl_match_data.values():
    
    prev_match_score = 0
    match_college_id = ''
    match_obj = pro_data
    pro_match_string = pro_data['nfl_match_string']
    
    for college_data in college_draft_data_clean:
        match_score = fuzz.ratio(pro_match_string, college_data['match_string'])
        
        
        if match_score > prev_match_score and match_score > min_score:
            match_obj['match_score'] = match_score
            match_obj['college_match_str'] = college_data['match_string']
            match_obj['college_id'] = college_data['playerId']
            match_obj['college_position'] = college_data['draftedPos']
            match_obj['draft_team_college_data'] = college_data['draftedBy']
            match_obj['draft_pick_college_data'] = college_data['draftedOverall']
           
            prev_match_score = match_score
        
        if match_score == 100:
            break
    
    matches.append(match_obj)

# %%
no_match = [match_obj for match_obj in matches if 'match_score' not in match_obj]

# %%
initial_matches = [match_obj for match_obj in matches if 'match_score' in match_obj]

# %%
actual_matches = [match for match in initial_matches 
                 if match['nfl_drafted_by'] == match['draft_team_college_data'] and
                     str(match['nfl_overall_pick']) == match['draft_pick_college_data']]

# %%
print(f'No match above 60%: {len(no_match)}')
print(f'Players with match scores greater than 60: {len(initial_matches)}')
print(f'Number of true positives: {len(actual_matches)}')
print(f'Number of false positives: {len(nfl_match_data.values()) - len(actual_matches)}')
print(f'Number of players: {len(nfl_match_data.values())}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-88a28f827975> in <module>
# ----> 1 print(f'No match above 60%: {len(no_match)}')
#       2 print(f'Players with match scores greater than 60: {len(initial_matches)}')
#       3 print(f'Number of true positives: {len(actual_matches)}')
#       4 print(f'Number of false positives: {len(nfl_match_data.values()) - len(actual_matches)}')
#       5 print(f'Number of players: {len(nfl_match_data.values())}')
#
# NameError: name 'no_match' is not defined

# %% [markdown]
# ## Save true positive matches

# %%
with open('./matches.json', 'w') as outfile:
    json.dump(actual_matches, outfile)

# %% [markdown]
# ## Find number of non matches of relevant positions
# Since we are not measuring success of players in the following positions: `['G', 'K', 'LS', 'P', 'T', 'OL', 'C']`, we will ignore non matches for these positions

# %%
false_matches = [match for match in initial_matches 
                 if match['nfl_drafted_by'] != match['draft_team_college_data'] or
                     str(match['nfl_overall_pick']) != match['draft_pick_college_data']]

# %%
no_match += false_matches
# Out:
# 1402

# %%
positions_in_matchless = set([player['nfl_position'] for player in no_match])

# %%
ignore_positions = ['G', 'K', 'LS', 'P', 'T', 'OL', 'C']

# %%
relevant_non_matches = [non_match for non_match in no_match if non_match['nfl_position'] not in ignore_positions]

# %%
len(relevant_non_matches)
# Out:
# 961

# %% [markdown]
# ## Ignore players drafted after 2019
#
# The college dataset only includes data from players through 2019.

# %%
all_draft_data = {}
for root, _, files in os.walk('./ProData/cleaned/draft_data'):
    for file in files:
        position = file.strip('.json')
        
        if position in ignore_positions:
            continue
        
        with open(f'{root}/{file}', 'r') as draft_data_file:
            draft_data = json.load(draft_data_file)
            
        for player_id, data in draft_data.items():
            all_draft_data = {**all_draft_data, **draft_data}

# %%
non_matches_with_draft_year = []
for player in relevant_non_matches:
    draft_year = all_draft_data[player['nfl_id']]['year']
    player['draft_year'] = int(re.sub('\*', '', draft_year))

# %%
college_data_cutoff_year = 2019

non_matches_pre_2020 = [player for player in relevant_non_matches 
                            if player['draft_year'] <= college_data_cutoff_year]

# %%
len(non_matches_pre_2020)
# Out:
# 722

# %% [markdown]
# ## Find percentage of matchless players by year drafted

# %%
draft_year_counts_missing_data = defaultdict(int)

for player in non_matches_pre_2020:
    draft_year = player['draft_year']
    draft_year_counts_missing_data[draft_year]+=1

missing_matches_by_year_perc = {}
for year, missing_matches_count in draft_year_counts_missing_data.items():
    missing_matches_by_year_perc[year] = 100 * missing_matches_count / len(non_matches_pre_2020)

sorted(missing_matches_by_year_perc.items(), key=lambda x: x[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a73da63e08f9> in <module>
# ----> 1 draft_year_counts_missing_data = defaultdict(int)
#       2
#       3 for player in non_matches_pre_2020:
#       4     draft_year = player['draft_year']
#       5     draft_year_counts_missing_data[draft_year]+=1
#
# NameError: name 'defaultdict' is not defined

# %% [markdown]
# # Find non matches that are statistically significant

# %% [markdown]
# ## Get all player data

# %%
season_data = {}

for root, _, files in os.walk('./ProData/results'):
    for file in files:
        draft_year, last_initial = file.strip('.json').split('_')

        with open(f'{root}/{file}', 'r') as player_data_file:
            nfl_player_data = json.load(player_data_file)

        for player_id, all_data in nfl_player_data.items():
            season_data[player_id] = all_data['career_statistics']

# %%
career_statistics = {}
for player in eligible_non_matches:
    player_id = player['nfl_id']
    
    career_statistics[player_id] = season_data[player_id].values()

# %%
from functools import reduce

# %%
def get_total_games_and_games_started(acc, curr):
    if 'gs' in curr and curr['gs']:
        acc['gs'] += int(curr['gs']) if len(curr['gs']) <= 2 else 0
    
    if 'g' in curr and curr['g']:
        acc['g'] += int(curr['g']) if len(curr['g']) <= 2 else 0
        
    if 'snaps_played' in curr and 'total_snaps' in curr:
        acc['snaps_played'] += curr['snaps_played']
        acc['total_snaps'] += round(curr['total_snaps'])
        acc['snap_perc'] = acc['snaps_played'] / acc['total_snaps'] if acc['total_snaps'] else 0
    return acc

# %%
missing_player_game_data = {}

for player_id, season_stats in career_statistics.items():
    reduce_init = {'gs': 0, 'g': 0, 'snap_perc': 0, 'snaps_played': 0, 'total_snaps': 0}
    game_data = reduce(get_total_games_and_games_started, season_stats, reduce_init)
    missing_player_game_data[player_id] = game_data

# %%
missing_player_game_data
# Out:
# {'AikeWa00': {'gs': 4,
#   'g': 93,
#   'snap_perc': 0.09418360196215837,
#   'snaps_played': 672,
#   'total_snaps': 7135},
#  'RobbFr20': {'gs': 148,
#   'g': 180,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BellYe20': {'gs': 107,
#   'g': 142,
#   'snap_perc': 0.9897674418604652,
#   'snaps_played': 2128,
#   'total_snaps': 2150},
#  'AndrWi20': {'gs': 0,
#   'g': 30,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'EmanKy00': {'gs': 32,
#   'g': 72,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RobiTr02': {'gs': 8,
#   'g': 38,
#   'snap_perc': 0.25341560158660204,
#   'snaps_played': 575,
#   'total_snaps': 2269},
#  'VandKy99': {'gs': 137,
#   'g': 152,
#   'snap_perc': 0.6199226305609284,
#   'snaps_played': 641,
#   'total_snaps': 1034},
#  'FreeDw00': {'gs': 157,
#   'g': 222,
#   'snap_perc': 0.5209707822808671,
#   'snaps_played': 2211,
#   'total_snaps': 4244},
#  'FreeEd20': {'gs': 0,
#   'g': 20,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FishTr20': {'gs': 74,
#   'g': 90,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FujiSc20': {'gs': 125,
#   'g': 143,
#   'snap_perc': 0.40939597315436244,
#   'snaps_played': 122,
#   'total_snaps': 298},
#  'FranBr20': {'gs': 0,
#   'g': 4,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BakeMi00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BannSh00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BurtSt00': {'gs': 3,
#   'g': 19,
#   'snap_perc': 0.2964102564102564,
#   'snaps_played': 289,
#   'total_snaps': 975},
#  'DaniTr20': {'gs': 28,
#   'g': 107,
#   'snap_perc': 0.31004366812227074,
#   'snaps_played': 284,
#   'total_snaps': 916},
#  'DaviCh22': {'gs': 25,
#   'g': 102,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PruiMy00': {'gs': 22,
#   'g': 74,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TollDa99': {'gs': 2,
#   'g': 78,
#   'snap_perc': 0.20991561181434598,
#   'snaps_played': 199,
#   'total_snaps': 948},
#  'CartAn20': {'gs': 147,
#   'g': 184,
#   'snap_perc': 0.3369098712446352,
#   'snaps_played': 471,
#   'total_snaps': 1398},
#  'ClemNa99': {'gs': 168,
#   'g': 180,
#   'snap_perc': 0.5797819623389494,
#   'snaps_played': 585,
#   'total_snaps': 1009},
#  'CoopJa20': {'gs': 10,
#   'g': 96,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CartJo01': {'gs': 1,
#   'g': 24,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CoopCh20': {'gs': 15,
#   'g': 86,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ChevRa20': {'gs': 0,
#   'g': 21,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GreeLa00': {'gs': 28,
#   'g': 53,
#   'snap_perc': 0.40488466757123476,
#   'snaps_played': 1492,
#   'total_snaps': 3685},
#  'GreeCh01': {'gs': 0,
#   'g': 3,
#   'snap_perc': 0.34946236559139787,
#   'snaps_played': 65,
#   'total_snaps': 186},
#  'WilsJi00': {'gs': 27,
#   'g': 73,
#   'snap_perc': 0.6258555133079848,
#   'snaps_played': 2469,
#   'total_snaps': 3945},
#  'SimsRy20': {'gs': 55,
#   'g': 105,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ShepLi99': {'gs': 79,
#   'g': 126,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'StamJo21': {'gs': 0,
#   'g': 4,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ScotGr20': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DonaDy00': {'gs': 0,
#   'g': 4,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PeteGr99': {'gs': 0,
#   'g': 14,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TaliLo00': {'gs': 0,
#   'g': 19,
#   'snap_perc': 0.14603409933283915,
#   'snaps_played': 197,
#   'total_snaps': 1349},
#  'TripJo00': {'gs': 3,
#   'g': 44,
#   'snap_perc': 0.049653579676674366,
#   'snaps_played': 129,
#   'total_snaps': 2598},
#  'CarrCo00': {'gs': 8,
#   'g': 46,
#   'snap_perc': 0.2673236834000616,
#   'snaps_played': 868,
#   'total_snaps': 3247},
#  'CataMi00': {'gs': 4,
#   'g': 29,
#   'snap_perc': 0.18144329896907216,
#   'snaps_played': 352,
#   'total_snaps': 1940},
#  'DrewDa00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GrifCo20': {'gs': 130,
#   'g': 146,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GoodDw20': {'gs': 1,
#   'g': 16,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GbajKa20': {'gs': 74,
#   'g': 124,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GranEr20': {'gs': 3,
#   'g': 24,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GranOr20': {'gs': 1,
#   'g': 27,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WarrTy20': {'gs': 93,
#   'g': 107,
#   'snap_perc': 0.07042253521126761,
#   'snaps_played': 5,
#   'total_snaps': 71},
#  'WilsEu20': {'gs': 86,
#   'g': 96,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WilkJi20': {'gs': 21,
#   'g': 119,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SkelJo00': {'gs': 17,
#   'g': 20,
#   'snap_perc': 0.6892778993435449,
#   'snaps_played': 315,
#   'total_snaps': 457},
#  'SchiSh99': {'gs': 0,
#   'g': 38,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SimsEu99': {'gs': 20,
#   'g': 99,
#   'snap_perc': 0.4776268477826608,
#   'snaps_played': 2391,
#   'total_snaps': 5006},
#  'StanR.00': {'gs': 1,
#   'g': 46,
#   'snap_perc': 0.13481152993348117,
#   'snaps_played': 304,
#   'total_snaps': 2255},
#  'McKiJe00': {'gs': 18,
#   'g': 83,
#   'snap_perc': 0.36348949919224555,
#   'snaps_played': 2025,
#   'total_snaps': 5571},
#  'MoorZa00': {'gs': 2,
#   'g': 26,
#   'snap_perc': 0.19439868204283361,
#   'snaps_played': 354,
#   'total_snaps': 1821},
#  'NewmTe20': {'gs': 205,
#   'g': 221,
#   'snap_perc': 0.8221350613915416,
#   'snaps_played': 4821,
#   'total_snaps': 5864},
#  'McInRo20': {'gs': 78,
#   'g': 124,
#   'snap_perc': 0.23594961240310078,
#   'snaps_played': 487,
#   'total_snaps': 2064},
#  'MannDa21': {'gs': 96,
#   'g': 128,
#   'snap_perc': 0.7653301886792453,
#   'snaps_played': 1947,
#   'total_snaps': 2544},
#  'McClRa00': {'gs': 4,
#   'g': 40,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HobbEl20': {'gs': 56,
#   'g': 79,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HaglTy20': {'gs': 19,
#   'g': 50,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LeexPa99': {'gs': 15,
#   'g': 55,
#   'snap_perc': 0.7595419847328244,
#   'snaps_played': 398,
#   'total_snaps': 524},
#  'LangKe98': {'gs': 113,
#   'g': 136,
#   'snap_perc': 0.6523282522447275,
#   'snaps_played': 3124,
#   'total_snaps': 4789},
#  'LyncCo99': {'gs': 12,
#   'g': 79,
#   'snap_perc': 0.4700854700854701,
#   'snaps_played': 495,
#   'total_snaps': 1053},
#  'HairNa00': {'gs': 17,
#   'g': 54,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LeSuJe20': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LawrNa00': {'gs': 5,
#   'g': 26,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KeitJo20': {'gs': 8,
#   'g': 23,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KacyIs20': {'gs': 22,
#   'g': 103,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HillSa99': {'gs': 48,
#   'g': 97,
#   'snap_perc': 0.43501252435290844,
#   'snaps_played': 1563,
#   'total_snaps': 3593},
#  'HodgSt99': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JohnJe21': {'gs': 0,
#   'g': 9,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'IngrCo00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MaddAn20': {'gs': 12,
#   'g': 35,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'McClDa21': {'gs': 0,
#   'g': 51,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MortCh20': {'gs': 3,
#   'g': 15,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'McCrBo20': {'gs': 37,
#   'g': 94,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MoldAn99': {'gs': 2,
#   'g': 51,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MoorKa99': {'gs': 13,
#   'g': 42,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MaysJo99': {'gs': 38,
#   'g': 78,
#   'snap_perc': 0.3859300476947536,
#   'snaps_played': 971,
#   'total_snaps': 2516},
#  'NixxJo20': {'gs': 0,
#   'g': 31,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JohnTr05': {'gs': 77,
#   'g': 102,
#   'snap_perc': 0.7729145942873383,
#   'snaps_played': 5439,
#   'total_snaps': 7037},
#  'MillHa00': {'gs': 2,
#   'g': 9,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KeisBr20': {'gs': 114,
#   'g': 156,
#   'snap_perc': 0.7410501193317423,
#   'snaps_played': 1863,
#   'total_snaps': 2514},
#  'LeonDa00': {'gs': 51,
#   'g': 51,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LaulKy00': {'gs': 0,
#   'g': 2,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HaroEl00': {'gs': 24,
#   'g': 61,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HarrWi02': {'gs': 19,
#   'g': 40,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KindSe99': {'gs': 0,
#   'g': 3,
#   'snap_perc': 0.15,
#   'snaps_played': 12,
#   'total_snaps': 80},
#  'KariDe00': {'gs': 0,
#   'g': 33,
#   'snap_perc': 0.08,
#   'snaps_played': 36,
#   'total_snaps': 450},
#  'KonzJa00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HendMa21': {'gs': 28,
#   'g': 44,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HughDa99': {'gs': 2,
#   'g': 53,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HiggJo00': {'gs': 11,
#   'g': 60,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HaywAd98': {'gs': 13,
#   'g': 118,
#   'snap_perc': 0.12677079549582274,
#   'snaps_played': 349,
#   'total_snaps': 2753},
#  'VealDe20': {'gs': 1,
#   'g': 37,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RobeAn00': {'gs': 41,
#   'g': 173,
#   'snap_perc': 0.34855055923305184,
#   'snaps_played': 3054,
#   'total_snaps': 8762},
#  'RobiZa00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BonnAl00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BryaAr00': {'gs': 4,
#   'g': 36,
#   'snap_perc': 0.36662606577344703,
#   'snaps_played': 903,
#   'total_snaps': 2463},
#  'BassDa00': {'gs': 11,
#   'g': 66,
#   'snap_perc': 0.3684997011356844,
#   'snaps_played': 1233,
#   'total_snaps': 3346},
#  'FrisBy20': {'gs': 0,
#   'g': 23,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FreeAr20': {'gs': 30,
#   'g': 74,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'EbukSa00': {'gs': 37,
#   'g': 72,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'AlleJa22': {'gs': 184,
#   'g': 190,
#   'snap_perc': 0.8950635530594148,
#   'snaps_played': 3028,
#   'total_snaps': 3383},
#  'RashSa20': {'gs': 4,
#   'g': 45,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RichKr20': {'gs': 1,
#   'g': 39,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RogeNi20': {'gs': 16,
#   'g': 56,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BaxtGa20': {'gs': 54,
#   'g': 62,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BladWi20': {'gs': 15,
#   'g': 20,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BannAl00': {'gs': 4,
#   'g': 57,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BerlEd00': {'gs': 1,
#   'g': 62,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BailRo21': {'gs': 1,
#   'g': 84,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ElliAt00': {'gs': 6,
#   'g': 15,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GoodAn20': {'gs': 95,
#   'g': 127,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GordLa00': {'gs': 15,
#   'g': 41,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GreeJa21': {'gs': 46,
#   'g': 121,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GreeHo20': {'gs': 20,
#   'g': 78,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GlovLa20': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CarmRo00': {'gs': 2,
#   'g': 19,
#   'snap_perc': 0.19005847953216373,
#   'snaps_played': 260,
#   'total_snaps': 1368},
#  'CartMa01': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WarrGe20': {'gs': 137,
#   'g': 163,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WinbJa20': {'gs': 37,
#   'g': 103,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WestEr20': {'gs': 4,
#   'g': 44,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WortSh20': {'gs': 0,
#   'g': 4,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WallRa20': {'gs': 3,
#   'g': 41,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WymsEl20': {'gs': 9,
#   'g': 95,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WeatCo20': {'gs': 0,
#   'g': 3,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DuprAl00': {'gs': 68,
#   'g': 87,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DeboAn00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PerkAn20': {'gs': 0,
#   'g': 5,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PettKe20': {'gs': 0,
#   'g': 25,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DenmSt00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CurlDa20': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CoxxTo21': {'gs': 4,
#   'g': 56,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SowaR.00': {'gs': 2,
#   'g': 13,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SlauT.20': {'gs': 32,
#   'g': 79,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SandLe20': {'gs': 29,
#   'g': 97,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ScotTo21': {'gs': 0,
#   'g': 23,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'StLoBr00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WilcJ.00': {'gs': 39,
#   'g': 82,
#   'snap_perc': 0.6124392220421394,
#   'snaps_played': 3023,
#   'total_snaps': 4936},
#  'WebbBW00': {'gs': 35,
#   'g': 80,
#   'snap_perc': 0.5656984785615491,
#   'snaps_played': 2863,
#   'total_snaps': 5061},
#  'DuraJu99': {'gs': 95,
#   'g': 128,
#   'snap_perc': 0.5728561468742738,
#   'snaps_played': 2465,
#   'total_snaps': 4303},
#  'DeOsZa99': {'gs': 0,
#   'g': 199,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TubbMa20': {'gs': 16,
#   'g': 29,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TorbRe20': {'gs': 28,
#   'g': 104,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TuftSe20': {'gs': 0,
#   'g': 15,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LaneAu99': {'gs': 17,
#   'g': 30,
#   'snap_perc': 0.4296455424274973,
#   'snaps_played': 400,
#   'total_snaps': 931},
#  'LeFeDa00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LissSe99': {'gs': 21,
#   'g': 69,
#   'snap_perc': 0.34134165366614666,
#   'snaps_played': 1094,
#   'total_snaps': 3205},
#  "O'ShJa00": {'gs': 36,
#   'g': 75,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HolcCu00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JoneCy00': {'gs': 2,
#   'g': 42,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JudoMa00': {'gs': 58,
#   'g': 85,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JohnBr98': {'gs': 0,
#   'g': 9,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'McMiJe00': {'gs': 2,
#   'g': 28,
#   'snap_perc': 0.41342567927543955,
#   'snaps_played': 776,
#   'total_snaps': 1877},
#  'McSuCa00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JohnTa20': {'gs': 37,
#   'g': 91,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JohnTr21': {'gs': 0,
#   'g': 35,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'NalbJo00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'NullKe00': {'gs': 4,
#   'g': 4,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MorrSy00': {'gs': 14,
#   'g': 15,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MorrRo20': {'gs': 67,
#   'g': 99,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'McKiAl20': {'gs': 42,
#   'g': 97,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MileJo20': {'gs': 0,
#   'g': 22,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MoorRo22': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MeieRo20': {'gs': 49,
#   'g': 138,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SiavJu20': {'gs': 6,
#   'g': 56,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SpenSh20': {'gs': 74,
#   'g': 100,
#   'snap_perc': 0.8473282442748091,
#   'snaps_played': 111,
#   'total_snaps': 131},
#  'StarRa20': {'gs': 147,
#   'g': 186,
#   'snap_perc': 0.5979793233082706,
#   'snaps_played': 2545,
#   'total_snaps': 4256},
#  'ScotDa20': {'gs': 28,
#   'g': 57,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SchoBo20': {'gs': 2,
#   'g': 29,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SopoIs20': {'gs': 95,
#   'g': 147,
#   'snap_perc': 0.3525046382189239,
#   'snaps_played': 570,
#   'total_snaps': 1617},
#  'SmitAn22': {'gs': 133,
#   'g': 186,
#   'snap_perc': 0.5725281231497927,
#   'snaps_played': 2901,
#   'total_snaps': 5067},
#  'GaroJi00': {'gs': 39,
#   'g': 55,
#   'snap_perc': 0.6868385345997287,
#   'snaps_played': 2531,
#   'total_snaps': 3685},
#  'ThomKi20': {'gs': 17,
#   'g': 110,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TaylSh20': {'gs': 2,
#   'g': 40,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ThomAd00': {'gs': 109,
#   'g': 135,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TownLe20': {'gs': 31,
#   'g': 65,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WellCh00': {'gs': 23,
#   'g': 51,
#   'snap_perc': 0.3,
#   'snaps_played': 150,
#   'total_snaps': 500},
#  'WebbLa99': {'gs': 86,
#   'g': 127,
#   'snap_perc': 0.7848691287199713,
#   'snaps_played': 4378,
#   'total_snaps': 5578},
#  'WrigDe99': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WillJa05': {'gs': 0,
#   'g': 4,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PalmNa01': {'gs': 12,
#   'g': 48,
#   'snap_perc': 0.25144138372837926,
#   'snaps_played': 785,
#   'total_snaps': 3122},
#  'PoweTy00': {'gs': 0,
#   'g': 19,
#   'snap_perc': 0.05,
#   'snaps_played': 60,
#   'total_snaps': 1200},
#  'ComiJo00': {'gs': 1,
#   'g': 25,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SmitRy00': {'gs': 17,
#   'g': 77,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SimsLe00': {'gs': 21,
#   'g': 69,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SandBe00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WillCa02': {'gs': 58,
#   'g': 81,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WelsJo20': {'gs': 0,
#   'g': 6,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GocoCh99': {'gs': 67,
#   'g': 79,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SimpJe00': {'gs': 37,
#   'g': 63,
#   'snap_perc': 0.5405034324942791,
#   'snaps_played': 1181,
#   'total_snaps': 2185},
#  'ShieAr00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'StudAn99': {'gs': 9,
#   'g': 97,
#   'snap_perc': 0.12207689258818867,
#   'snaps_played': 308,
#   'total_snaps': 2523},
#  'SherMa00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PickRy20': {'gs': 185,
#   'g': 207,
#   'snap_perc': 0.436222005842259,
#   'snaps_played': 1344,
#   'total_snaps': 3081},
#  'PollTo21': {'gs': 64,
#   'g': 73,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PeteWi20': {'gs': 60,
#   'g': 97,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PerrRa21': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DowlRa00': {'gs': 2,
#   'g': 12,
#   'snap_perc': 0.17682020802377416,
#   'snaps_played': 119,
#   'total_snaps': 673},
#  'GoedDa00': {'gs': 33,
#   'g': 50,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BartRo20': {'gs': 77,
#   'g': 102,
#   'snap_perc': 0.8793969849246231,
#   'snaps_played': 350,
#   'total_snaps': 398},
#  'BabiJo20': {'gs': 133,
#   'g': 185,
#   'snap_perc': 0.6506875477463713,
#   'snaps_played': 3407,
#   'total_snaps': 5236},
#  'BeckJo20': {'gs': 0,
#   'g': 26,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BryaAn20': {'gs': 6,
#   'g': 15,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BrowC.20': {'gs': 62,
#   'g': 83,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BrouNe00': {'gs': 0,
#   'g': 6,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FeltJe00': {'gs': 52,
#   'g': 137,
#   'snap_perc': 0.29534740725558517,
#   'snaps_played': 1441,
#   'total_snaps': 4879},
#  'EdwaRo20': {'gs': 96,
#   'g': 139,
#   'snap_perc': 0.42,
#   'snaps_played': 315,
#   'total_snaps': 750},
#  'ReidCa00': {'gs': 16,
#   'g': 55,
#   'snap_perc': 0.3371998920960345,
#   'snaps_played': 1250,
#   'total_snaps': 3707},
#  'AbraJo00': {'gs': 175,
#   'g': 192,
#   'snap_perc': 0.7560296846011132,
#   'snaps_played': 1630,
#   'total_snaps': 2156},
#  'AndeRa21': {'gs': 9,
#   'g': 27,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'AustRe20': {'gs': 4,
#   'g': 18,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BardRa00': {'gs': 1,
#   'g': 29,
#   'snap_perc': 0.2701298701298701,
#   'snaps_played': 208,
#   'total_snaps': 770},
#  'BomaRh00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PaceCa20': {'gs': 153,
#   'g': 187,
#   'snap_perc': 0.7614201183431952,
#   'snaps_played': 3217,
#   'total_snaps': 4225},
#  'PierTe20': {'gs': 0,
#   'g': 18,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PeteKe21': {'gs': 15,
#   'g': 76,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PierSh20': {'gs': 0,
#   'g': 12,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PattEl20': {'gs': 0,
#   'g': 14,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WillQu01': {'gs': 13,
#   'g': 25,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WebsKe00': {'gs': 5,
#   'g': 17,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TrouTo00': {'gs': 2,
#   'g': 21,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TracAd99': {'gs': 0,
#   'g': 16,
#   'snap_perc': 0.07003089598352215,
#   'snaps_played': 68,
#   'total_snaps': 971},
#  'ToonTi00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CoxxDe99': {'gs': 56,
#   'g': 63,
#   'snap_perc': 0.713128038897893,
#   'snaps_played': 1320,
#   'total_snaps': 1851},
#  'CareDo00': {'gs': 22,
#   'g': 100,
#   'snap_perc': 0.18296755725190839,
#   'snaps_played': 767,
#   'total_snaps': 4192},
#  'WalkMi01': {'gs': 35,
#   'g': 48,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'StatJi00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'StarTy00': {'gs': 0,
#   'g': 1,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CoheTa00': {'gs': 22,
#   'g': 51,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GordAm20': {'gs': 6,
#   'g': 34,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ShepNa00': {'gs': 8,
#   'g': 47,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SielZa00': {'gs': 12,
#   'g': 39,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'StroGr00': {'gs': 3,
#   'g': 20,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ThomBr21': {'gs': 104,
#   'g': 157,
#   'snap_perc': 0.45982694684796044,
#   'snaps_played': 372,
#   'total_snaps': 809},
#  'TripLa20': {'gs': 62,
#   'g': 92,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GarcPi00': {'gs': 131,
#   'g': 148,
#   'snap_perc': 0.7768732347566041,
#   'snaps_played': 4676,
#   'total_snaps': 6019},
#  'DownEr20': {'gs': 13,
#   'g': 45,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DenmAn20': {'gs': 0,
#   'g': 27,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WellMa00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CastLu20': {'gs': 79,
#   'g': 82,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CodySh20': {'gs': 68,
#   'g': 112,
#   'snap_perc': 0.30011723329425555,
#   'snaps_played': 256,
#   'total_snaps': 853},
#  'CollNi20': {'gs': 95,
#   'g': 95,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CodyDa20': {'gs': 0,
#   'g': 2,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CantCh21': {'gs': 128,
#   'g': 148,
#   'snap_perc': 0.505259586019681,
#   'snaps_played': 1489,
#   'total_snaps': 2947},
#  'ColeTr20': {'gs': 154,
#   'g': 176,
#   'snap_perc': 0.6621649698732599,
#   'snaps_played': 3187,
#   'total_snaps': 4813},
#  'GrugKa00': {'gs': 25,
#   'g': 77,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GathRi00': {'gs': 4,
#   'g': 15,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ElliKe01': {'gs': 5,
#   'g': 56,
#   'snap_perc': 0.2059089538739825,
#   'snaps_played': 683,
#   'total_snaps': 3317},
#  'FranJo02': {'gs': 10,
#   'g': 39,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FounDa00': {'gs': 0,
#   'g': 6,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RodgDo99': {'gs': 121,
#   'g': 162,
#   'snap_perc': 0.7186366932559826,
#   'snaps_played': 4955,
#   'total_snaps': 6895},
#  'FinnCo20': {'gs': 111,
#   'g': 133,
#   'snap_perc': 0.8596161083929243,
#   'snaps_played': 2284,
#   'total_snaps': 2657},
#  'BoylNi00': {'gs': 50,
#   'g': 73,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'VickKe99': {'gs': 44,
#   'g': 86,
#   'snap_perc': 0.3644630989856593,
#   'snaps_played': 1042,
#   'total_snaps': 2859},
#  'BuntSe00': {'gs': 24,
#   'g': 33,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BallCo00': {'gs': 4,
#   'g': 37,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BellQu00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'AdamPh00': {'gs': 11,
#   'g': 79,
#   'snap_perc': 0.3414500683994528,
#   'snaps_played': 1248,
#   'total_snaps': 3655},
#  'EasoNi20': {'gs': 21,
#   'g': 117,
#   'snap_perc': 0.2,
#   'snaps_played': 218,
#   'total_snaps': 1090},
#  'UrlaBr00': {'gs': 180,
#   'g': 182,
#   'snap_perc': 0.9203084832904884,
#   'snaps_played': 716,
#   'total_snaps': 778},
#  'VakaFu00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FordDe00': {'gs': 43,
#   'g': 85,
#   'snap_perc': 0.5397540273687857,
#   'snaps_played': 3116,
#   'total_snaps': 5773},
#  'FedeTe00': {'gs': 0,
#   'g': 51,
#   'snap_perc': 0.1804255319148936,
#   'snaps_played': 636,
#   'total_snaps': 3525},
#  'BossKe00': {'gs': 58,
#   'g': 74,
#   'snap_perc': 0.35,
#   'snaps_played': 49,
#   'total_snaps': 140},
#  'BaldJo99': {'gs': 0,
#   'g': 3,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BarkRa99': {'gs': 0,
#   'g': 6,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RatlKe20': {'gs': 12,
#   'g': 77,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HughMo00': {'gs': 1,
#   'g': 25,
#   'snap_perc': 0.24158653846153846,
#   'snaps_played': 402,
#   'total_snaps': 1664},
#  'HepbBr00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LymaDu00': {'gs': 21,
#   'g': 55,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LarrKa20': {'gs': 6,
#   'g': 19,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LarsLe20': {'gs': 5,
#   'g': 16,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KrauRy00': {'gs': 1,
#   'g': 14,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HampCa00': {'gs': 164,
#   'g': 173,
#   'snap_perc': 0.5,
#   'snaps_played': 495,
#   'total_snaps': 990},
#  'HodgSe20': {'gs': 43,
#   'g': 63,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HaywRe20': {'gs': 59,
#   'g': 92,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HartEd20': {'gs': 57,
#   'g': 77,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KillMi00': {'gs': 4,
#   'g': 86,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MallJo20': {'gs': 1,
#   'g': 48,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MassCh00': {'gs': 1,
#   'g': 32,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JackJo01': {'gs': 15,
#   'g': 42,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JohnTa01': {'gs': 27,
#   'g': 46,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'NelsJJ00': {'gs': 16,
#   'g': 58,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'NixoTa00': {'gs': 0,
#   'g': 2,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'YounBr20': {'gs': 89,
#   'g': 123,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MeieKe00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MoatAr00': {'gs': 45,
#   'g': 121,
#   'snap_perc': 0.29540191862388354,
#   'snaps_played': 1786,
#   'total_snaps': 6046},
#  'MariMa00': {'gs': 5,
#   'g': 64,
#   'snap_perc': 0.20735009671179883,
#   'snaps_played': 536,
#   'total_snaps': 2585},
#  'McClRo98': {'gs': 32,
#   'g': 97,
#   'snap_perc': 0.5769317924314525,
#   'snaps_played': 2546,
#   'total_snaps': 4413},
#  'JameKe00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JaniJe00': {'gs': 1,
#   'g': 51,
#   'snap_perc': 0.12478184991273997,
#   'snaps_played': 429,
#   'total_snaps': 3438},
#  'NkanCh99': {'gs': 0,
#   'g': 23,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'NdukCh99': {'gs': 31,
#   'g': 55,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LawrQu00': {'gs': 1,
#   'g': 6,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HallDe99': {'gs': 162,
#   'g': 178,
#   'snap_perc': 0.8291513955455314,
#   'snaps_played': 2941,
#   'total_snaps': 3547},
#  'HillMa21': {'gs': 0,
#   'g': 13,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HargAn20': {'gs': 27,
#   'g': 106,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LangBr00': {'gs': 0,
#   'g': 16,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HayeWi99': {'gs': 46,
#   'g': 137,
#   'snap_perc': 0.4452748712838399,
#   'snaps_played': 2681,
#   'total_snaps': 6021},
#  'HighTi00': {'gs': 45,
#   'g': 77,
#   'snap_perc': 0.28233904311872415,
#   'snaps_played': 478,
#   'total_snaps': 1693},
#  'HillLe00': {'gs': 22,
#   'g': 74,
#   'snap_perc': 0.3300970873786408,
#   'snaps_played': 272,
#   'total_snaps': 824},
#  'HallAl99': {'gs': 2,
#   'g': 32,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KnigRo20': {'gs': 2,
#   'g': 48,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KoloRo20': {'gs': 19,
#   'g': 54,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KocuKr20': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HargJa00': {'gs': 72,
#   'g': 87,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HallDe02': {'gs': 0,
#   'g': 23,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HillTy00': {'gs': 66,
#   'g': 83,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HemiTe00': {'gs': 0,
#   'g': 21,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HolmTy01': {'gs': 0,
#   'g': 15,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HousDe00': {'gs': 2,
#   'g': 73,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JaspMi00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'NashKe21': {'gs': 0,
#   'g': 2,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'McBrTr00': {'gs': 3,
#   'g': 17,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JohnJa23': {'gs': 132,
#   'g': 184,
#   'snap_perc': 0.5533728687916976,
#   'snaps_played': 1493,
#   'total_snaps': 2698},
#  'JuneCa99': {'gs': 73,
#   'g': 89,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JosuSt20': {'gs': 0,
#   'g': 4,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MoreJi00': {'gs': 10,
#   'g': 32,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WortDo99': {'gs': 0,
#   'g': 8,
#   'snap_perc': 0.17228464419475656,
#   'snaps_played': 92,
#   'total_snaps': 534},
#  'SullJo23': {'gs': 16,
#   'g': 36,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ShiaVi00': {'gs': 90,
#   'g': 149,
#   'snap_perc': 0.2585669781931464,
#   'snaps_played': 83,
#   'total_snaps': 321},
#  'SamuAs20': {'gs': 133,
#   'g': 157,
#   'snap_perc': 0.7811568276684556,
#   'snaps_played': 1310,
#   'total_snaps': 1677},
#  'SmitZu00': {'gs': 0,
#   'g': 9,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SapeLa20': {'gs': 0,
#   'g': 10,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CharIk20': {'gs': 3,
#   'g': 53,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ClanKe20': {'gs': 46,
#   'g': 109,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ChapLa20': {'gs': 0,
#   'g': 8,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CombCh21': {'gs': 0,
#   'g': 10,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CowsDe20': {'gs': 0,
#   'g': 32,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PoweWa00': {'gs': 2,
#   'g': 13,
#   'snap_perc': 0.29508196721311475,
#   'snaps_played': 306,
#   'total_snaps': 1037},
#  'TyleTa99': {'gs': 21,
#   'g': 49,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ToeaMa99': {'gs': 24,
#   'g': 36,
#   'snap_perc': 0.4301675977653631,
#   'snaps_played': 77,
#   'total_snaps': 179},
#  'ThigTy00': {'gs': 12,
#   'g': 30,
#   'snap_perc': 0.060085836909871244,
#   'snaps_played': 14,
#   'total_snaps': 233},
#  'DockDa20': {'gs': 156,
#   'g': 158,
#   'snap_perc': 0.7952038369304556,
#   'snaps_played': 1658,
#   'total_snaps': 2085},
#  'WithWi20': {'gs': 159,
#   'g': 195,
#   'snap_perc': 0.2567368936795688,
#   'snaps_played': 524,
#   'total_snaps': 2041},
#  'WireCo20': {'gs': 26,
#   'g': 127,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WeslDa20': {'gs': 2,
#   'g': 107,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WhitGr99': {'gs': 23,
#   'g': 63,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WansTi20': {'gs': 6,
#   'g': 13,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ShorCe00': {'gs': 43,
#   'g': 70,
#   'snap_perc': 0.7390761548064919,
#   'snaps_played': 2960,
#   'total_snaps': 4005},
#  'SkriBu00': {'gs': 92,
#   'g': 152,
#   'snap_perc': 0.7932692307692307,
#   'snaps_played': 7425,
#   'total_snaps': 9360},
#  'SmitD.00': {'gs': 9,
#   'g': 24,
#   'snap_perc': 0.8601398601398601,
#   'snaps_played': 369,
#   'total_snaps': 429},
#  'ColeB.00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GreeMo20': {'gs': 108,
#   'g': 125,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PittDa99': {'gs': 1,
#   'g': 7,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TartJa00': {'gs': 56,
#   'g': 72,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ThomMy00': {'gs': 0,
#   'g': 1,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TullDa00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DevaSe00': {'gs': 16,
#   'g': 57,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'EdmoCh00': {'gs': 13,
#   'g': 54,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BryaWe20': {'gs': 9,
#   'g': 29,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BuchPh20': {'gs': 85,
#   'g': 132,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BeckTo20': {'gs': 6,
#   'g': 56,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BoimRo20': {'gs': 27,
#   'g': 103,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BernRo20': {'gs': 60,
#   'g': 160,
#   'snap_perc': 0.5,
#   'snaps_played': 386,
#   'total_snaps': 772},
#  'BullCo20': {'gs': 1,
#   'g': 20,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BrigLa20': {'gs': 0,
#   'g': 30,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ReynJa20': {'gs': 0,
#   'g': 18,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RogeSh99': {'gs': 130,
#   'g': 163,
#   'snap_perc': 0.4296724470134875,
#   'snaps_played': 223,
#   'total_snaps': 519},
#  'ReedJa21': {'gs': 32,
#   'g': 99,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RambKe00': {'gs': 0,
#   'g': 29,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RobeTy20': {'gs': 0,
#   'g': 12,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'EvanFr21': {'gs': 6,
#   'g': 95,
#   'snap_perc': 0.3197311569851176,
#   'snaps_played': 666,
#   'total_snaps': 2083},
#  'FlorDr20': {'gs': 104,
#   'g': 157,
#   'snap_perc': 0.6441539578794481,
#   'snaps_played': 887,
#   'total_snaps': 1377},
#  'FranAu20': {'gs': 94,
#   'g': 142,
#   'snap_perc': 0.336986301369863,
#   'snaps_played': 615,
#   'total_snaps': 1825},
#  'ButlDo99': {'gs': 67,
#   'g': 85,
#   'snap_perc': 0.6602806861216306,
#   'snaps_played': 2964,
#   'total_snaps': 4489},
#  'BattDa99': {'gs': 4,
#   'g': 16,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'AddeNa00': {'gs': 21,
#   'g': 26,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'VaugDa20': {'gs': 0,
#   'g': 48,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TaboTe00': {'gs': 5,
#   'g': 25,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TysoMi00': {'gs': 2,
#   'g': 10,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DesiPi00': {'gs': 45,
#   'g': 81,
#   'snap_perc': 0.5757243195785777,
#   'snaps_played': 2623,
#   'total_snaps': 4556},
#  'SmitQu00': {'gs': 0,
#   'g': 15,
#   'snap_perc': 0.30009871668311944,
#   'snaps_played': 304,
#   'total_snaps': 1013},
#  'SoreBr00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SmitJa02': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TateBr00': {'gs': 20,
#   'g': 127,
#   'snap_perc': 0.18765596406587923,
#   'snaps_played': 1128,
#   'total_snaps': 6011},
#  'ToleGr99': {'gs': 49,
#   'g': 88,
#   'snap_perc': 0.6368015414258189,
#   'snaps_played': 2644,
#   'total_snaps': 4152},
#  'TeelMi00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WashMa99': {'gs': 113,
#   'g': 131,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WalkDa21': {'gs': 84,
#   'g': 109,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WarrSt20': {'gs': 0,
#   'g': 25,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WeslGr20': {'gs': 103,
#   'g': 118,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WilsGi21': {'gs': 0,
#   'g': 5,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WoodCe20': {'gs': 29,
#   'g': 61,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WheeDa20': {'gs': 0,
#   'g': 5,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GreeJa20': {'gs': 0,
#   'g': 9,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CromJo00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CanfSe00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TuckJu20': {'gs': 107,
#   'g': 147,
#   'snap_perc': 0.6898134863701578,
#   'snaps_played': 2404,
#   'total_snaps': 3485},
#  'ParkWi01': {'gs': 21,
#   'g': 78,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DaniOw00': {'gs': 125,
#   'g': 131,
#   'snap_perc': 0.8024760832864378,
#   'snaps_played': 2852,
#   'total_snaps': 3554},
#  'DougRe20': {'gs': 54,
#   'g': 107,
#   'snap_perc': 0.3929458519622454,
#   'snaps_played': 791,
#   'total_snaps': 2013},
#  'SmitJu20': {'gs': 217,
#   'g': 221,
#   'snap_perc': 0.7489389487430623,
#   'snaps_played': 2294,
#   'total_snaps': 3063},
#  'SeymRi00': {'gs': 157,
#   'g': 164,
#   'snap_perc': 0.6603415559772297,
#   'snaps_played': 348,
#   'total_snaps': 527},
#  'StroMa01': {'gs': 129,
#   'g': 146,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SchoAa99': {'gs': 128,
#   'g': 133,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SmitKe23': {'gs': 10,
#   'g': 36,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SmitDw20': {'gs': 83,
#   'g': 117,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SpooBr20': {'gs': 14,
#   'g': 14,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ScotCe20': {'gs': 0,
#   'g': 13,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SteeMa20': {'gs': 11,
#   'g': 42,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'StewDa20': {'gs': 1,
#   'g': 35,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ScotCa20': {'gs': 0,
#   'g': 8,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SandTe20': {'gs': 15,
#   'g': 80,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WhitCo01': {'gs': 25,
#   'g': 73,
#   'snap_perc': 0.5648616125150421,
#   'snaps_played': 2347,
#   'total_snaps': 4155},
#  'DionSh00': {'gs': 7,
#   'g': 46,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DonnKe00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GateCl00': {'gs': 4,
#   'g': 32,
#   'snap_perc': 0.33363228699551567,
#   'snaps_played': 372,
#   'total_snaps': 1115},
#  'CravKe20': {'gs': 1,
#   'g': 22,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ColeKe20': {'gs': 81,
#   'g': 141,
#   'snap_perc': 0.37020316027088035,
#   'snaps_played': 164,
#   'total_snaps': 443},
#  'AtogO.20': {'gs': 83,
#   'g': 101,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BentBi00': {'gs': 8,
#   'g': 20,
#   'snap_perc': 0.5247603833865815,
#   'snaps_played': 657,
#   'total_snaps': 1252},
#  'BethJu00': {'gs': 14,
#   'g': 158,
#   'snap_perc': 0.2064343163538874,
#   'snaps_played': 1309,
#   'total_snaps': 6341},
#  'BiluCh00': {'gs': 0,
#   'g': 29,
#   'snap_perc': 0.24895977808599168,
#   'snaps_played': 359,
#   'total_snaps': 1442},
#  'FataMa20': {'gs': 26,
#   'g': 45,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FlemRo20': {'gs': 0,
#   'g': 6,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'EdwaDw20': {'gs': 64,
#   'g': 136,
#   'snap_perc': 0.5693848354792561,
#   'snaps_played': 1990,
#   'total_snaps': 3495},
#  'AgneJa00': {'gs': 4,
#   'g': 54,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ArmaAl00': {'gs': 5,
#   'g': 64,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BullKe00': {'gs': 138,
#   'g': 170,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BlacAv00': {'gs': 0,
#   'g': 25,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BerrGa20': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BrooRo20': {'gs': 0,
#   'g': 5,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BoonAl20': {'gs': 41,
#   'g': 129,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RobeDe20': {'gs': 90,
#   'g': 92,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LewiTr99': {'gs': 7,
#   'g': 18,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HazeMa01': {'gs': 1,
#   'g': 9,
#   'snap_perc': 0.07344632768361582,
#   'snaps_played': 39,
#   'total_snaps': 531},
#  'HarrSh00': {'gs': 42,
#   'g': 76,
#   'snap_perc': 0.489344752041426,
#   'snaps_played': 2457,
#   'total_snaps': 5021},
#  'KelsCh21': {'gs': 120,
#   'g': 147,
#   'snap_perc': 0.46991869918699186,
#   'snaps_played': 289,
#   'total_snaps': 615},
#  'KlecDa20': {'gs': 6,
#   'g': 63,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KircDa00': {'gs': 2,
#   'g': 28,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KellEt20': {'gs': 9,
#   'g': 36,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'OwusAk99': {'gs': 4,
#   'g': 18,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LewiDe02': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HestDe99': {'gs': 34,
#   'g': 147,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HatcJa20': {'gs': 69,
#   'g': 147,
#   'snap_perc': 0.6561936646922483,
#   'snaps_played': 2548,
#   'total_snaps': 3883},
#  'HawkBr20': {'gs': 0,
#   'g': 20,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KearFr00': {'gs': 8,
#   'g': 35,
#   'snap_perc': 0.28302900107411383,
#   'snaps_played': 527,
#   'total_snaps': 1862},
#  'HallP.00': {'gs': 27,
#   'g': 40,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HernCh00': {'gs': 26,
#   'g': 41,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HarrDa05': {'gs': 9,
#   'g': 34,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'OSulJ.00': {'gs': 8,
#   'g': 17,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'IworPr00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MerrSh99': {'gs': 59,
#   'g': 75,
#   'snap_perc': 0.3097744360902256,
#   'snaps_played': 206,
#   'total_snaps': 665},
#  'MillJu99': {'gs': 12,
#   'g': 49,
#   'snap_perc': 0.02,
#   'snaps_played': 2,
#   'total_snaps': 100},
#  'McCoMa20': {'gs': 13,
#   'g': 72,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MathJe00': {'gs': 0,
#   'g': 15,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MoslC.20': {'gs': 31,
#   'g': 140,
#   'snap_perc': 0.4138817480719794,
#   'snaps_played': 1610,
#   'total_snaps': 3890},
#  'McCoLe00': {'gs': 4,
#   'g': 10,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MarsKe20': {'gs': 0,
#   'g': 1,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JenkKr00': {'gs': 102,
#   'g': 108,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MossAv00': {'gs': 10,
#   'g': 22,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MuhaAl00': {'gs': 17,
#   'g': 60,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'McQuLe01': {'gs': 1,
#   'g': 1,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MoorDa03': {'gs': 14,
#   'g': 49,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'NugeDa21': {'gs': 1,
#   'g': 24,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MartVa99': {'gs': 27,
#   'g': 51,
#   'snap_perc': 0.48906560636182905,
#   'snaps_played': 492,
#   'total_snaps': 1006},
#  'MiddWi98': {'gs': 12,
#   'g': 49,
#   'snap_perc': 0.2301013024602026,
#   'snaps_played': 159,
#   'total_snaps': 691},
#  'JuszKy00': {'gs': 91,
#   'g': 130,
#   'snap_perc': 0.45331266950794263,
#   'snaps_played': 3510,
#   'total_snaps': 7743},
#  'JohnRu02': {'gs': 0,
#   'g': 1,
#   'snap_perc': 0.18055555555555555,
#   'snaps_played': 13,
#   'total_snaps': 72},
#  'RappTa00': {'gs': 24,
#   'g': 33,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'UmenOs99': {'gs': 102,
#   'g': 161,
#   'snap_perc': 0.5359168241965974,
#   'snaps_played': 1701,
#   'total_snaps': 3174},
#  'ElliSh00': {'gs': 166,
#   'g': 184,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FostBr00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FolsJ.99': {'gs': 0,
#   'g': 2,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'AlfoRo00': {'gs': 80,
#   'g': 97,
#   'snap_perc': 0.8654826254826254,
#   'snaps_played': 5604,
#   'total_snaps': 6475},
#  'RoweJe00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BallDa20': {'gs': 23,
#   'g': 74,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FordRu00': {'gs': 3,
#   'g': 49,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BierKr99': {'gs': 37,
#   'g': 114,
#   'snap_perc': 0.6492130750605327,
#   'snaps_played': 2145,
#   'total_snaps': 3304},
#  'AndeSc00': {'gs': 8,
#   'g': 34,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BoehMo00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BateTr00': {'gs': 0,
#   'g': 10,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FielRo20': {'gs': 25,
#   'g': 87,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FitzRy00': {'gs': 147,
#   'g': 166,
#   'snap_perc': 0.8807403284163652,
#   'snaps_played': 6329,
#   'total_snaps': 7186},
#  'CannTr00': {'gs': 0,
#   'g': 49,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CrosKe00': {'gs': 4,
#   'g': 52,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DaviDo23': {'gs': 0,
#   'g': 14,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WaldEr99': {'gs': 88,
#   'g': 147,
#   'snap_perc': 0.7057500803083842,
#   'snaps_played': 4394,
#   'total_snaps': 6226},
#  'TafoJo20': {'gs': 9,
#   'g': 76,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TurnT.21': {'gs': 0,
#   'g': 2,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PendJe00': {'gs': 0,
#   'g': 5,
#   'snap_perc': 0.22530864197530864,
#   'snaps_played': 73,
#   'total_snaps': 324},
#  'GuntRo00': {'gs': 38,
#   'g': 77,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CromAn20': {'gs': 137,
#   'g': 162,
#   'snap_perc': 0.9348359741129212,
#   'snaps_played': 4189,
#   'total_snaps': 4481},
#  'ShroDa20': {'gs': 1,
#   'g': 23,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GardCh00': {'gs': 27,
#   'g': 38,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DaviHa21': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0.15942028985507245,
#   'snaps_played': 22,
#   'total_snaps': 138},
#  'DImpRy00': {'gs': 1,
#   'g': 12,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TaylCo01': {'gs': 0,
#   'g': 16,
#   'snap_perc': 0.05714285714285714,
#   'snaps_played': 54,
#   'total_snaps': 945},
#  'PeteJu00': {'gs': 147,
#   'g': 158,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PoteHa20': {'gs': 26,
#   'g': 121,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PhilMa20': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ParkJe21': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PolkDa20': {'gs': 16,
#   'g': 95,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ScotDo99': {'gs': 5,
#   'g': 33,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SidbLa99': {'gs': 0,
#   'g': 50,
#   'snap_perc': 0.07776261937244201,
#   'snaps_played': 57,
#   'total_snaps': 733},
#  'ScotBe00': {'gs': 3,
#   'g': 49,
#   'snap_perc': 0.12267657992565056,
#   'snaps_played': 33,
#   'total_snaps': 269},
#  'SchoNi99': {'gs': 0,
#   'g': 13,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GrahCo99': {'gs': 74,
#   'g': 184,
#   'snap_perc': 0.706380027739251,
#   'snaps_played': 5093,
#   'total_snaps': 7210},
#  'ClinHa00': {'gs': 99,
#   'g': 106,
#   'snap_perc': 0.9662081847512312,
#   'snaps_played': 5690,
#   'total_snaps': 5889},
#  'CarrTr00': {'gs': 54,
#   'g': 110,
#   'snap_perc': 0.6557795698924731,
#   'snaps_played': 4879,
#   'total_snaps': 7440},
#  'ShahAd00': {'gs': 24,
#   'g': 51,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SmitJu00': {'gs': 51,
#   'g': 63,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'StewGr00': {'gs': 39,
#   'g': 71,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SaubEr00': {'gs': 9,
#   'g': 49,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WillDe22': {'gs': 68,
#   'g': 138,
#   'snap_perc': 0.3899782135076253,
#   'snaps_played': 358,
#   'total_snaps': 918},
#  'WaddMi20': {'gs': 5,
#   'g': 33,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WillCo21': {'gs': 74,
#   'g': 126,
#   'snap_perc': 0.4899328859060403,
#   'snaps_played': 219,
#   'total_snaps': 447},
#  'WynnDe20': {'gs': 1,
#   'g': 51,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JennRa00': {'gs': 54,
#   'g': 93,
#   'snap_perc': 0.4959593627337797,
#   'snaps_played': 2148,
#   'total_snaps': 4331},
#  'IoanJu20': {'gs': 5,
#   'g': 36,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'IssaJa20': {'gs': 5,
#   'g': 23,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'McCrDe00': {'gs': 16,
#   'g': 49,
#   'snap_perc': 0.3441775615688659,
#   'snaps_played': 1132,
#   'total_snaps': 3289},
#  'MellAa00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'McCaDa00': {'gs': 3,
#   'g': 41,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MondMa20': {'gs': 0,
#   'g': 7,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MyerLe20': {'gs': 1,
#   'g': 18,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MerrTh20': {'gs': 0,
#   'g': 15,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MissDw20': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JonePa20': {'gs': 104,
#   'g': 146,
#   'snap_perc': 0.7339149400218102,
#   'snaps_played': 4711,
#   'total_snaps': 6419},
#  'JameEr20': {'gs': 12,
#   'g': 28,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JackVi00': {'gs': 137,
#   'g': 155,
#   'snap_perc': 0.895924308588064,
#   'snaps_played': 3693,
#   'total_snaps': 4122},
#  'JeffJa21': {'gs': 1,
#   'g': 34,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'OluoFo00': {'gs': 32,
#   'g': 55,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LegrMa00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LindKo00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HaynAl20': {'gs': 98,
#   'g': 130,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HillCh20': {'gs': 0,
#   'g': 16,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HuntPe20': {'gs': 6,
#   'g': 36,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HannRy00': {'gs': 5,
#   'g': 54,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HeinKe00': {'gs': 3,
#   'g': 22,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'OshiBa20': {'gs': 0,
#   'g': 2,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LongRi20': {'gs': 4,
#   'g': 39,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LeexJa21': {'gs': 1,
#   'g': 9,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LeJeNo20': {'gs': 0,
#   'g': 7,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HarbCl00': {'gs': 38,
#   'g': 101,
#   'snap_perc': 0.37318215430120777,
#   'snaps_played': 1514,
#   'total_snaps': 4057},
#  'HartLa99': {'gs': 0,
#   'g': 14,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'JoneJa03': {'gs': 33,
#   'g': 132,
#   'snap_perc': 0.35216346153846156,
#   'snaps_played': 1172,
#   'total_snaps': 3328},
#  'NixILo00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0.08,
#   'snaps_played': 22,
#   'total_snaps': 275},
#  'MathRa99': {'gs': 165,
#   'g': 175,
#   'snap_perc': 0.8233128834355828,
#   'snaps_played': 2684,
#   'total_snaps': 3260},
#  'MannRi20': {'gs': 38,
#   'g': 84,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'MathRo20': {'gs': 121,
#   'g': 192,
#   'snap_perc': 0.6545875096376252,
#   'snaps_played': 2547,
#   'total_snaps': 3891},
#  'JohnDa10': {'gs': 0,
#   'g': 33,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'NichBi00': {'gs': 41,
#   'g': 52,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'NealSi00': {'gs': 1,
#   'g': 55,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'OnyeDa00': {'gs': 42,
#   'g': 80,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KingEr20': {'gs': 4,
#   'g': 66,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HickAk00': {'gs': 108,
#   'g': 149,
#   'snap_perc': 0.6651927437641724,
#   'snaps_played': 5867,
#   'total_snaps': 8820},
#  'LewiDa20': {'gs': 65,
#   'g': 141,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'LeveOt20': {'gs': 1,
#   'g': 17,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'OmonXa00': {'gs': 0,
#   'g': 7,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'OdomAn20': {'gs': 52,
#   'g': 74,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'OrrxRa20': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KpasTa00': {'gs': 29,
#   'g': 68,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KuppCo00': {'gs': 49,
#   'g': 63,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'KnoxJo00': {'gs': 27,
#   'g': 45,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HovaCh20': {'gs': 149,
#   'g': 156,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HaggCl20': {'gs': 104,
#   'g': 172,
#   'snap_perc': 0.06995230524642289,
#   'snaps_played': 44,
#   'total_snaps': 629},
#  'HarrAn21': {'gs': 2,
#   'g': 52,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'HillJo21': {'gs': 11,
#   'g': 27,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RiveDe00': {'gs': 0,
#   'g': 24,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'VashNa99': {'gs': 51,
#   'g': 87,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FordJa99': {'gs': 8,
#   'g': 43,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BryaC.00': {'gs': 0,
#   'g': 12,
#   'snap_perc': 0.01,
#   'snaps_played': 2,
#   'total_snaps': 200},
#  'RichDa97': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'AdamAn20': {'gs': 74,
#   'g': 121,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'AbduKh20': {'gs': 0,
#   'g': 16,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'AnguRi00': {'gs': 6,
#   'g': 27,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'EdwaAr00': {'gs': 0,
#   'g': 43,
#   'snap_perc': 0.10777957860615883,
#   'snaps_played': 133,
#   'total_snaps': 1234},
#  'EaslMa00': {'gs': 0,
#   'g': 29,
#   'snap_perc': 0.039679358717434866,
#   'snaps_played': 99,
#   'total_snaps': 2495},
#  'EddsA.99': {'gs': 0,
#   'g': 21,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RollAn20': {'gs': 146,
#   'g': 155,
#   'snap_perc': 0.9797149122807017,
#   'snaps_played': 3574,
#   'total_snaps': 3648},
#  'RothMa20': {'gs': 54,
#   'g': 100,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'RiddRy20': {'gs': 0,
#   'g': 17,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'VitaDa00': {'gs': 13,
#   'g': 44,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'FurmJo00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'BlacWi20': {'gs': 30,
#   'g': 96,
#   'snap_perc': 0.652542372881356,
#   'snaps_played': 2387,
#   'total_snaps': 3658},
#  'BethAn20': {'gs': 200,
#   'g': 209,
#   'snap_perc': 0.952517447657029,
#   'snaps_played': 7643,
#   'total_snaps': 8024},
#  'QuicBr00': {'gs': 27,
#   'g': 84,
#   'snap_perc': 0.3914925654056089,
#   'snaps_played': 2080,
#   'total_snaps': 5313},
#  'AlleCo00': {'gs': 18,
#   'g': 56,
#   'snap_perc': 0.670547147846333,
#   'snaps_played': 1728,
#   'total_snaps': 2577},
#  'BateJe00': {'gs': 56,
#   'g': 56,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ElliJa00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ChriMa00': {'gs': 2,
#   'g': 65,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'GrigBo20': {'gs': 1,
#   'g': 45,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WatsGa20': {'gs': 21,
#   'g': 62,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WalkHu00': {'gs': 100,
#   'g': 183,
#   'snap_perc': 0.6950916433675054,
#   'snaps_played': 4475,
#   'total_snaps': 6438},
#  'WebbDe20': {'gs': 1,
#   'g': 11,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SmelDe00': {'gs': 0,
#   'g': 2,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SmitTy01': {'gs': 7,
#   'g': 41,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SterNe00': {'gs': 6,
#   'g': 35,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SimoDe00': {'gs': 1,
#   'g': 16,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PaleAn20': {'gs': 1,
#   'g': 36,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'PopeMo20': {'gs': 21,
#   'g': 48,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ThomJu00': {'gs': 53,
#   'g': 71,
#   'snap_perc': 0.7196074057550748,
#   'snaps_played': 3226,
#   'total_snaps': 4483},
#  'ColcRi20': {'gs': 1,
#   'g': 43,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CordJo20': {'gs': 0,
#   'g': 19,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CrayPa00': {'gs': 36,
#   'g': 105,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'CramCa00': {'gs': 3,
#   'g': 29,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'ClauJa20': {'gs': 2,
#   'g': 29,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'WestTe00': {'gs': 23,
#   'g': 49,
#   'snap_perc': 0.35709219858156027,
#   'snaps_played': 1007,
#   'total_snaps': 2820},
#  'WebsLa00': {'gs': 0,
#   'g': 1,
#   'snap_perc': 0.30158730158730157,
#   'snaps_played': 19,
#   'total_snaps': 63},
#  'WestLa00': {'gs': 0,
#   'g': 0,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'StonDa99': {'gs': 0,
#   'g': 20,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'StanDe00': {'gs': 0,
#   'g': 13,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DixoRo00': {'gs': 3,
#   'g': 37,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DiggNa20': {'gs': 138,
#   'g': 170,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'DennPa20': {'gs': 13,
#   'g': 41,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SpeeEJ00': {'gs': 0,
#   'g': 36,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'SticEa00': {'gs': 0,
#   'g': 1,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0},
#  'TrufMa20': {'gs': 125,
#   'g': 136,
#   'snap_perc': 0.4699599465954606,
#   'snaps_played': 352,
#   'total_snaps': 749},
#  'ThomCh23': {'gs': 30,
#   'g': 98,
#   'snap_perc': 0,
#   'snaps_played': 0,
#   'total_snaps': 0}}

# %%
players_who_played = [player_id for player_id, game_info in missing_player_game_data.items()
                                if game_info['snap_perc'] > 0.3]

# %%
# before snap data was taken
len([player_id for player_id, game_info in missing_player_game_data.items()
                                if game_info['total_snaps'] == 0])
# Out:
# 429
