# %%
import requests
import string
from bs4 import BeautifulSoup
import time
from pprint import pprint
import json
import random

# %% [markdown]
# ## Part two takes the results from part one via the player_dict.json file and gathers pro links that are present on the page.
# ## Pro links will be saved to the dictionary object.

# %%
'''
Load in player_dict.json file to a dictionary object.
'''

with open('player_dict.json') as json_file:
    player_dict = json.load(json_file)

# %%
def get_hrefPro(all_hrefs) -> str:
    '''
    Takes input of all hrefs for a single player url.  If the pro link is on the page then
    it will retrun a string of the pro link URL.  Else it will return None.
    '''
    
    for href in all_hrefs:
        temp_href = str(href.get("href"))
        if 'pro-football-reference.com/players' in temp_href:
            return temp_href
    return None

# %%
def get_player_proLink(collegeLink:str) -> str:
    '''
    Takes input of a single college player url link and will return their pro link if it exists.
    Else it will return None.
    Dependency on function get_hrefPro.
    '''
    
    request = requests.get(collegeLink)
    time.sleep(.3)
    soup = BeautifulSoup(request.text, "html.parser")
    all_hrefs = soup.find_all("a")

    return get_hrefPro(all_hrefs)

# %%
'''
Test URL and results.
'''

test = get_player_proLink('https://www.sports-reference.com/cfb/players/amari-cooper-1.html')
print(test)
# Out:
# https://www.pro-football-reference.com/players/C/CoopAm00.htm

# %%
def save_json(number:int):
    '''
    Function to be used in main code that will save progress for every 500 players checked.
    '''
    
    if number % 500 == 0:
        with open("player_dict.json", 'w') as outfile:
            json.dump(player_dict, outfile)
        print("Saved JSON")
    return

# %%
'''
Main code that will go through all college players in the player_dict object and check if the there is a pro link on their page.
If there is a pro link on the page then it will acquire the pro link and add it to the player_dict object.  if there is no
pro link on the page then the value of prolink will value it with None.  This main code will also save the player_dict object
to the player_dict.json file.  The code will skip over rows where the prolink is already valued allowing for this code to be stopped
and then picked up again and run later from where it left off.
Dependency on functions save_json, get_player_proLink, get_hrefPro
'''

rand_list = [.2,.4,.6,.7,.8,.3,.1,1,.9, 3,.6,.7,.8]
collegeCount = 0
proCount = 0

for letter in player_dict:
    print(f"Starting for letter {letter}\nTotal in letter {len(player_dict[letter]['playerIds'])}")
    collegeCount += len(player_dict[letter]['playerIds'])
    tempProCount = 0
    tempRandnum = 0
    for i in range(len(player_dict[letter]['playerIds'])):
        
        if 'proLink' in player_dict[letter]['Body'][i]:
            if player_dict[letter]['Body'][i]['proLink'] == None:
                continue
            else:
                tempProCount += 1
                continue
        
        print(f"Checking for player {player_dict[letter]['playerIds'][i]}\nCount {i} out of {len(player_dict[letter]['playerIds'])}")
        proLink = get_player_proLink(player_dict[letter]['Body'][i]['collegeLink'])
        player_dict[letter]['Body'][i]['proLink'] = proLink
        
        tempRandnum = random.choice(rand_list)
        
        if proLink == None:
            print(f"No professional stats found.\nWating {tempRandnum}")
        else:
            tempProCount += 1
            print(f"Professional stats found. Added Link\nWating {tempRandnum}")
        print("--------------------------\n")
    
        time.sleep(tempRandnum)
        save_json(i)
    
    print(f"Total Professional Links found for letter {letter} {tempProCount}","\n-----------------------------\n")
    proCount+=tempProCount
    
    with open("player_dict.json", 'w') as outfile:
        json.dump(player_dict, outfile)
    
    if tempRandnum != 0:
        time.sleep(30)

print(f"Total count of all College links {collegeCount}")      
print(f"Total count of all professional links {proCount}")
# Out:
# Starting for letter a
# Total in letter 4219
# Total Professional Links found for letter a 440
# -----------------------------
#
# Starting for letter b
# Total in letter 12603
# Total Professional Links found for letter b 1372
# -----------------------------
#
# Starting for letter c
# Total in letter 9264
# Total Professional Links found for letter c 959
# -----------------------------
#
# Starting for letter d
# Total in letter 6121
# Total Professional Links found for letter d 623
# -----------------------------
#
# Starting for letter e
# Total in letter 2396
# Total Professional Links found for letter e 245
# -----------------------------
#
# Starting for letter f
# Total in letter 4582
# Total Professional Links found for letter f 445
# -----------------------------
#
# Starting for letter g
# Total in letter 6319
# Total Professional Links found for letter g 658
# -----------------------------
#
# Starting for letter h
# Total in letter 10027
# Total Professional Links found for letter h 1048
# -----------------------------
#
# Starting for letter i
# Total in letter 569
# Total Professional Links found for letter i 76
# -----------------------------
#
# Starting for letter j
# Total in letter 5741
# Total Professional Links found for letter j 674
# -----------------------------
#
# Starting for letter k
# Total in letter 4045
# Total Professional Links found for letter k 371
# -----------------------------
#
# Starting for letter l
# Total in letter 5567
# Total Professional Links found for letter l 549
# -----------------------------
#
# Starting for letter m
# Total in letter 12067
# Total Professional Links found for letter m 1213
# -----------------------------
#
# Starting for letter n
# Total in letter 2167
# Total Professional Links found for letter n 233
# -----------------------------
#
# Starting for letter o
# Total in letter 1892
# Total Professional Links found for letter o 189
# -----------------------------
#
# Starting for letter p
# Total in letter 6121
# Total Professional Links found for letter p 536
# -----------------------------
#
# Starting for letter q
# Total in letter 178
# Total Professional Links found for letter q 21
# -----------------------------
#
# Starting for letter r
# Total in letter 6408
# Total Professional Links found for letter r 615
# -----------------------------
#
# Starting for letter s
# Total in letter 12013
# Total Professional Links found for letter s 1173
# -----------------------------
#
# Starting for letter t
# Total in letter 5244
# Total Professional Links found for letter t 559
# -----------------------------
#
# Starting for letter u
# Total in letter 339
# Total Professional Links found for letter u 32
# -----------------------------
#
# Starting for letter v
# Total in letter 1342
# Total Professional Links found for letter v 117
# -----------------------------
#
# Starting for letter w
# Total in letter 9381
# Total Professional Links found for letter w 1046
# -----------------------------
#
# Starting for letter x
# Total in letter 3
# Total Professional Links found for letter x 1
# -----------------------------
#
# Starting for letter y
# Total in letter 685
# Total Professional Links found for letter y 65
# -----------------------------
#
# Starting for letter z
# Total in letter 483
# Checking for player keith-zinger-1
# Count 333 out of 483
# Professional stats found. Added Link
# Wating 0.6
# --------------------------
#
# Checking for player chuck-zingler-1
# Count 334 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player fred-zingler-1
# Count 335 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player greg-zingler-1
# Count 336 out of 483
# No professional stats found.
# Wating 3
# --------------------------
#
# Checking for player allen-zink-1
# Count 337 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player andrew-zink-1
# Count 338 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player bob-zink-1
# Count 339 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player ed-zink-1
# Count 340 out of 483
# No professional stats found.
# Wating 1
# --------------------------
#
# Checking for player dave-zinkham-1
# Count 341 out of 483
# No professional stats found.
# Wating 1
# --------------------------
#
# Checking for player justin-zinn-1
# Count 342 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player eddie-zinn-turner-1
# Count 343 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player roger-zino-1
# Count 344 out of 483
# No professional stats found.
# Wating 0.2
# --------------------------
#
# Checking for player tom-zins-1
# Count 345 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player zak-zinter-1
# Count 346 out of 483
# No professional stats found.
# Wating 3
# --------------------------
#
# Checking for player jake-ziolkowski-1
# Count 347 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player dan-zion-1
# Count 348 out of 483
# No professional stats found.
# Wating 3
# --------------------------
#
# Checking for player curt-zipfel-1
# Count 349 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player keon-zipperer-1
# Count 350 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player paul-zipperlen-1
# Count 351 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player tom-zipperly-1
# Count 352 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player craig-zirbel-1
# Count 353 out of 483
# No professional stats found.
# Wating 0.4
# --------------------------
#
# Checking for player jared-zirkel-1
# Count 354 out of 483
# No professional stats found.
# Wating 0.4
# --------------------------
#
# Checking for player doug-zirkle-1
# Count 355 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player lou-zirkle-1
# Count 356 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player steve-zisk-1
# Count 357 out of 483
# No professional stats found.
# Wating 3
# --------------------------
#
# Checking for player doug-zismann-1
# Count 358 out of 483
# No professional stats found.
# Wating 1
# --------------------------
#
# Checking for player joel-zitek-1
# Count 359 out of 483
# No professional stats found.
# Wating 0.4
# --------------------------
#
# Checking for player tommy-zitiello-1
# Count 360 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player dennis-zito-1
# Count 361 out of 483
# No professional stats found.
# Wating 0.9
# --------------------------
#
# Checking for player bill-zittel-1
# Count 362 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player ray-zitzloff-1
# Count 363 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player bill-zivic-1
# Count 364 out of 483
# No professional stats found.
# Wating 0.9
# --------------------------
#
# Checking for player lubo-zizakovic-1
# Count 365 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player tony-zizzo-1
# Count 366 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player tanner-zlab-1
# Count 367 out of 483
# No professional stats found.
# Wating 0.3
# --------------------------
#
# Checking for player duane-zlatnik-1
# Count 368 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player bill-zloch-1
# Count 369 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player jan-zlotnick-1
# Count 370 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player alex-zmolik-1
# Count 371 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player paul-zmuida-1
# Count 372 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player tony-zoetis-1
# Count 373 out of 483
# No professional stats found.
# Wating 0.9
# --------------------------
#
# Checking for player mickey-zofko-1
# Count 374 out of 483
# Professional stats found. Added Link
# Wating 0.7
# --------------------------
#
# Checking for player zach-zoglio-1
# Count 375 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player scott-zolak-1
# Count 376 out of 483
# Professional stats found. Added Link
# Wating 0.1
# --------------------------
#
# Checking for player dylan-zolezzi-1
# Count 377 out of 483
# No professional stats found.
# Wating 1
# --------------------------
#
# Checking for player justin-zollar-1
# Count 378 out of 483
# No professional stats found.
# Wating 3
# --------------------------
#
# Checking for player derek-zoller-1
# Count 379 out of 483
# No professional stats found.
# Wating 0.9
# --------------------------
#
# Checking for player ron-zollicoffer-1
# Count 380 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player greg-zolman-1
# Count 381 out of 483
# No professional stats found.
# Wating 1
# --------------------------
#
# Checking for player greg-zolninger-1
# Count 382 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player eric-zomalt-1
# Count 383 out of 483
# Professional stats found. Added Link
# Wating 0.7
# --------------------------
#
# Checking for player greg-zomalt-1
# Count 384 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player joe-zombek-1
# Count 385 out of 483
# Professional stats found. Added Link
# Wating 0.7
# --------------------------
#
# Checking for player frank-zombo-1
# Count 386 out of 483
# Professional stats found. Added Link
# Wating 0.3
# --------------------------
#
# Checking for player john-zook-1
# Count 387 out of 483
# Professional stats found. Added Link
# Wating 0.9
# --------------------------
#
# Checking for player peter-zophy-1
# Count 388 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player cam-zopp-1
# Count 389 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player alex-zordich-1
# Count 390 out of 483
# No professional stats found.
# Wating 0.2
# --------------------------
#
# Checking for player michael-zordich-1
# Count 391 out of 483
# Professional stats found. Added Link
# Wating 0.6
# --------------------------
#
# Checking for player michael-zordich-2
# Count 392 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player chris-zorich-1
# Count 393 out of 483
# Professional stats found. Added Link
# Wating 0.1
# --------------------------
#
# Checking for player ben-zorn-1
# Count 394 out of 483
# No professional stats found.
# Wating 0.3
# --------------------------
#
# Checking for player greg-zoschak-1
# Count 395 out of 483
# No professional stats found.
# Wating 0.4
# --------------------------
#
# Checking for player cj-zotz-1
# Count 396 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player paul-zoubek-1
# Count 397 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player austin-zouzalik-1
# Count 398 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player mike-zouzalik-1
# Count 399 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player niadre-zouzoua-1
# Count 400 out of 483
# No professional stats found.
# Wating 3
# --------------------------
#
# Checking for player tom-zovko-1
# Count 401 out of 483
# No professional stats found.
# Wating 1
# --------------------------
#
# Checking for player andrew-zow-1
# Count 402 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player larry-zowada-1
# Count 403 out of 483
# No professional stats found.
# Wating 0.2
# --------------------------
#
# Checking for player tommy-zozus-1
# Count 404 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player logan-zschernitz-1
# Count 405 out of 483
# No professional stats found.
# Wating 0.9
# --------------------------
#
# Checking for player thomas-zsiros-1
# Count 406 out of 483
# No professional stats found.
# Wating 0.3
# --------------------------
#
# Checking for player john-zuanich-1
# Count 407 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player farwan-zubedi-1
# Count 408 out of 483
# No professional stats found.
# Wating 0.9
# --------------------------
#
# Checking for player isaiah-zuber-1
# Count 409 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player bud-zuberer-1
# Count 410 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player ernest-zuberer-1
# Count 411 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player ernie-zuberer-1
# Count 412 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player blake-zubovic-1
# Count 413 out of 483
# No professional stats found.
# Wating 0.4
# --------------------------
#
# Checking for player tim-zubradt-1
# Count 414 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player jim-zucali-1
# Count 415 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player david-zuccarelli-1
# Count 416 out of 483
# No professional stats found.
# Wating 0.3
# --------------------------
#
# Checking for player bob-zuccarini-1
# Count 417 out of 483
# No professional stats found.
# Wating 0.9
# --------------------------
#
# Checking for player vic-zucco-1
# Count 418 out of 483
# Professional stats found. Added Link
# Wating 0.8
# --------------------------
#
# Checking for player andrew-zuckerman-1
# Count 419 out of 483
# No professional stats found.
# Wating 0.2
# --------------------------
#
# Checking for player bob-zuckert-1
# Count 420 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player larry-zuercher-1
# Count 421 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player matt-zuercher-1
# Count 422 out of 483
# No professional stats found.
# Wating 0.2
# --------------------------
#
# Checking for player graham-zug-1
# Count 423 out of 483
# No professional stats found.
# Wating 0.4
# --------------------------
#
# Checking for player joe-zuger-1
# Count 424 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player dave-zuhars-1
# Count 425 out of 483
# No professional stats found.
# Wating 0.9
# --------------------------
#
# Checking for player micah-zuhl-1
# Count 426 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player trey-zuhn-iii-1
# Count 427 out of 483
# No professional stats found.
# Wating 0.9
# --------------------------
#
# Checking for player jacob-zuhr-1
# Count 428 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player paul-zukauskas-1
# Count 429 out of 483
# Professional stats found. Added Link
# Wating 0.3
# --------------------------
#
# Checking for player david-zulandt-1
# Count 430 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player kyle-zuleger-1
# Count 431 out of 483
# No professional stats found.
# Wating 0.3
# --------------------------
#
# Checking for player vince-zullo-1
# Count 432 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player javier-zuluaga-1
# Count 433 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player dave-zumbach-1
# Count 434 out of 483
# No professional stats found.
# Wating 0.3
# --------------------------
#
# Checking for player jim-zumbahlen-1
# Count 435 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player alex-zumberge-1
# Count 436 out of 483
# No professional stats found.
# Wating 0.3
# --------------------------
#
# Checking for player tim-zumbro-1
# Count 437 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player erick-zumwalt-1
# Count 438 out of 483
# No professional stats found.
# Wating 0.4
# --------------------------
#
# Checking for player jordan-zumwalt-1
# Count 439 out of 483
# Professional stats found. Added Link
# Wating 0.8
# --------------------------
#
# Checking for player rich-zumwalt-1
# Count 440 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player matt-zundel-1
# Count 441 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player mike-zunic-1
# Count 442 out of 483
# No professional stats found.
# Wating 1
# --------------------------
#
# Checking for player mike-zunica-1
# Count 443 out of 483
# Professional stats found. Added Link
# Wating 0.3
# --------------------------
#
# Checking for player larry-zunich-1
# Count 444 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player jabari-zuniga-1
# Count 445 out of 483
# Professional stats found. Added Link
# Wating 0.1
# --------------------------
#
# Checking for player wes-zunker-1
# Count 446 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player mike-zupan-1
# Count 447 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player jake-zupancic-1
# Count 448 out of 483
# No professional stats found.
# Wating 0.3
# --------------------------
#
# Checking for player john-zupancic-1
# Count 449 out of 483
# No professional stats found.
# Wating 1
# --------------------------
#
# Checking for player mike-zupancic-1
# Count 450 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player john-zupicich-1
# Count 451 out of 483
# No professional stats found.
# Wating 0.2
# --------------------------
#
# Checking for player tom-zuppke-1
# Count 452 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player randy-zur-1
# Count 453 out of 483
# No professional stats found.
# Wating 0.3
# --------------------------
#
# Checking for player rod-zur-1
# Count 454 out of 483
# No professional stats found.
# Wating 0.4
# --------------------------
#
# Checking for player chris-zurbrugg-1
# Count 455 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player mike-zurburgg-1
# Count 456 out of 483
# No professional stats found.
# Wating 0.2
# --------------------------
#
# Checking for player jeff-zurcher-1
# Count 457 out of 483
# No professional stats found.
# Wating 1
# --------------------------
#
# Checking for player kevin-zureki-1
# Count 458 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player anthony-zurisko-1
# Count 459 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player bill-zurzolo-1
# Count 460 out of 483
# No professional stats found.
# Wating 0.4
# --------------------------
#
# Checking for player jeremy-zuttah-1
# Count 461 out of 483
# Professional stats found. Added Link
# Wating 0.6
# --------------------------
#
# Checking for player jerry-zuver-1
# Count 462 out of 483
# No professional stats found.
# Wating 0.4
# --------------------------
#
# Checking for player mark-zuvich-1
# Count 463 out of 483
# No professional stats found.
# Wating 1
# --------------------------
#
# Checking for player jake-zuzek-1
# Count 464 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player brent-zuzo-1
# Count 465 out of 483
# No professional stats found.
# Wating 0.2
# --------------------------
#
# Checking for player aaron-zwahlen-1
# Count 466 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player lynn-zwahlen-1
# Count 467 out of 483
# No professional stats found.
# Wating 3
# --------------------------
#
# Checking for player drew-zwald-1
# Count 468 out of 483
# No professional stats found.
# Wating 0.3
# --------------------------
#
# Checking for player tom-zwayer-1
# Count 469 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player justin-zwick-1
# Count 470 out of 483
# No professional stats found.
# Wating 0.1
# --------------------------
#
# Checking for player jr-zwierzynski-1
# Count 471 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player jared-zwilling-1
# Count 472 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Checking for player zach-zwinak-1
# Count 473 out of 483
# Professional stats found. Added Link
# Wating 0.7
# --------------------------
#
# Checking for player bob-zwirko-1
# Count 474 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player jonny-zwitt-1
# Count 475 out of 483
# No professional stats found.
# Wating 0.9
# --------------------------
#
# Checking for player daniel-zychlinski-1
# Count 476 out of 483
# No professional stats found.
# Wating 0.6
# --------------------------
#
# Checking for player ted-zychowski-1
# Count 477 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player miguel-zyniewicz-1
# Count 478 out of 483
# No professional stats found.
# Wating 3
# --------------------------
#
# Checking for player tom-zyroll-1
# Count 479 out of 483
# No professional stats found.
# Wating 0.9
# --------------------------
#
# Checking for player don-zysk-1
# Count 480 out of 483
# No professional stats found.
# Wating 0.9
# --------------------------
#
# Checking for player al-zyskowski-1
# Count 481 out of 483
# No professional stats found.
# Wating 0.7
# --------------------------
#
# Checking for player alex-zyskowski-1
# Count 482 out of 483
# No professional stats found.
# Wating 0.8
# --------------------------
#
# Total Professional Links found for letter z 43
# -----------------------------
#
# Total count of all College links 129776
# Total count of all professional links 13303

# %%
'''
Test player_dict object.  Validate reuslts.
'''

player_dict['a']['Body'][2247]
# Out:
# {'collegeLink': 'https://www.sports-reference.com/cfb/players/andre-anderson-2.html',
#  'proLink': 'https://www.pro-football-reference.com/players/A/AndeAn23.htm'}

# %%
'''
Validate player_dict counts for each letter.
'''

for row in player_dict:
    print(row)
    print("PlayerIds", len(player_dict[row]['playerIds']))
    print("Body", len(player_dict[row]['Body']),'\n')
# Out:
# a
# PlayerIds 4219
# Body 4219
#
# b
# PlayerIds 12603
# Body 12603
#
# c
# PlayerIds 9264
# Body 9264
#
# d
# PlayerIds 6121
# Body 6121
#
# e
# PlayerIds 2396
# Body 2396
#
# f
# PlayerIds 4582
# Body 4582
#
# g
# PlayerIds 6319
# Body 6319
#
# h
# PlayerIds 10027
# Body 10027
#
# i
# PlayerIds 569
# Body 569
#
# j
# PlayerIds 5741
# Body 5741
#
# k
# PlayerIds 4045
# Body 4045
#
# l
# PlayerIds 5567
# Body 5567
#
# m
# PlayerIds 12067
# Body 12067
#
# n
# PlayerIds 2167
# Body 2167
#
# o
# PlayerIds 1892
# Body 1892
#
# p
# PlayerIds 6121
# Body 6121
#
# q
# PlayerIds 178
# Body 178
#
# r
# PlayerIds 6408
# Body 6408
#
# s
# PlayerIds 12013
# Body 12013
#
# t
# PlayerIds 5244
# Body 5244
#
# u
# PlayerIds 339
# Body 339
#
# v
# PlayerIds 1342
# Body 1342
#
# w
# PlayerIds 9381
# Body 9381
#
# x
# PlayerIds 3
# Body 3
#
# y
# PlayerIds 685
# Body 685
#
# z
# PlayerIds 483
# Body 483
